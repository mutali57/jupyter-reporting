# %%
import openpyxl 
import requests
import json
from datetime import datetime
import pandas as pd
df = pd.DataFrame()
# input datetime
from pytz import timezone
from datetime import datetime

def timestamp(iso_str, tz):
    dt = datetime.fromisoformat(iso_str) # or strptime
    return tz.localize(dt).timestamp()

tz = timezone("Africa/Johannesburg")
 # 1646143200.

start = timestamp("2023-01-01T00:00", tz)
end = timestamp("2023-01-31T23:00", tz)

print('Seconds since epoch:', start)
def jprint(obj):
    # create a formatted string of the Python JSON object
    text = json.dumps(obj, sort_keys=True, indent=4)
    print(text)
parameters = {
"username":"harmattan",
"password":"r6DmHGhf"
}
response = requests.post("https://southafrica.higeco.com/api/v1/authenticate",json=parameters)

tk = json.loads(response.text)['token']

print (tk)


mid = "https://southafrica.higeco.com/api/v1/plants/118/devices/3163FTFGI39D/3163NATGIB452051744/items/2051744749/items/"
#midget="https://southafrica.higeco.com//api/v1/getLogData/118/3163FTFGI39D/2051744/2051744749?from=1458811054&to=1458897454&samplingTime=2678400&maxSampleNumber=1000"

midpv1="https://southafrica.higeco.com/api/v1/getLogData/118/3163FTFGI39D/2051744/2051744749/?from="+str(int(start))+"&to="+str(int(end))+"&samplingTime=3600&maxSampleNumber=10000"
durbpv1="https://southafrica.higeco.com/api/v1/getLogData/119/3163NATGIB45/2051275/2051275280?from="+str(int(start))+"&to="+str(int(end))+"&samplingTime=3600&maxSampleNumber=10000"
durbpv2="https://southafrica.higeco.com/api/v1/getLogData/119/3163NATGIB45/2053313/2053313318?from="+str(int(start))+"&to="+str(int(end))+"&samplingTime=3600&maxSampleNumber=10000"
verpv1="https://southafrica.higeco.com/api/v1/getLogData/131/3163KATGI1CB/2051275/2051275281?from="+str(int(start))+"&to="+str(int(end))+"&samplingTime=3600&maxSampleNumber=10000"
verpv2="https://southafrica.higeco.com/api/v1/getLogData/131/3163KATGI1CB/2053249/2053249252?from="+str(int(start))+"&to="+str(int(end))+"&samplingTime=3600&maxSampleNumber=10000"
herpv1="https://southafrica.higeco.com/api/v1/getLogData/146/3963QVYGI0F0/2051855/2051855860?from="+str(int(start))+"&to="+str(int(end))+"&samplingTime=3600&maxSampleNumber=10000"
higpv1="https://southafrica.higeco.com/api/v1/getLogData/158/3763JJYGI3ED/2050140/2050140144?from="+str(int(start))+"&to="+str(int(end))+"&samplingTime=3600&maxSampleNumber=10000"
higpv2="https://southafrica.higeco.com/api/v1/getLogData/158/3763JJYGI3ED/2052927/2052927931?from="+str(int(start))+"&to="+str(int(end))+"&samplingTime=3600&maxSampleNumber=10000"
tznpv1="https://southafrica.higeco.com/api/v1/getLogData/157/3763PJYGI10B/2051493/2051493498?from="+str(int(start))+"&to="+str(int(end))+"&samplingTime=3600&maxSampleNumber=10000"

mid = "https://southafrica.higeco.com/api/v1/plants/158/devices/3763JJYGI3ED/"
#v1/getMergedLogData/158/3763JJYGI3ED/:devType
headers = {
        "accept" : "application/json",
        "Authorization": str(tk)}
response = requests.get(mid, headers=headers)
if response.status_code != 200:
    print('error: ' + str(response.status_code))
else:
    print('User List Loaded Successfully')
    jprint(response.json())
    #print (type(response.json()['data']) )
    #df = pd.DataFrame(response.json()['data'], columns=['Date', 'PA-PV1 kWh'])
    #df['Date'] = [datetime.fromtimestamp(x) for x in df['Date']]
    
    
   # df2 = pd.DataFrame(response.json())
   # df2
#print ( response.json())
#print(response.json())
# Out:
# Seconds since epoch: 1672524000.0
# afnzp2PDxGztfj8DTzxctATh
# User List Loaded Successfully
# {
#     "connectionStatus": 1,
#     "description": "",
#     "hwType": "GWC_V4",
#     "id": "3763JJYGI3ED",
#     "ip": "10.9.1.70",
#     "name": "Mediclinic Highveld",
#     "port": 8001,
#     "powerStatus": 1,
#     "version": "22.1.31"
# }

# %%
import pytz
pytz.all_timezones
# Out:
# ['Africa/Abidjan',
#  'Africa/Accra',
#  'Africa/Addis_Ababa',
#  'Africa/Algiers',
#  'Africa/Asmara',
#  'Africa/Asmera',
#  'Africa/Bamako',
#  'Africa/Bangui',
#  'Africa/Banjul',
#  'Africa/Bissau',
#  'Africa/Blantyre',
#  'Africa/Brazzaville',
#  'Africa/Bujumbura',
#  'Africa/Cairo',
#  'Africa/Casablanca',
#  'Africa/Ceuta',
#  'Africa/Conakry',
#  'Africa/Dakar',
#  'Africa/Dar_es_Salaam',
#  'Africa/Djibouti',
#  'Africa/Douala',
#  'Africa/El_Aaiun',
#  'Africa/Freetown',
#  'Africa/Gaborone',
#  'Africa/Harare',
#  'Africa/Johannesburg',
#  'Africa/Juba',
#  'Africa/Kampala',
#  'Africa/Khartoum',
#  'Africa/Kigali',
#  'Africa/Kinshasa',
#  'Africa/Lagos',
#  'Africa/Libreville',
#  'Africa/Lome',
#  'Africa/Luanda',
#  'Africa/Lubumbashi',
#  'Africa/Lusaka',
#  'Africa/Malabo',
#  'Africa/Maputo',
#  'Africa/Maseru',
#  'Africa/Mbabane',
#  'Africa/Mogadishu',
#  'Africa/Monrovia',
#  'Africa/Nairobi',
#  'Africa/Ndjamena',
#  'Africa/Niamey',
#  'Africa/Nouakchott',
# ...

# %%
def production(url,sheet):
    headers = {
        "accept" : "application/json",
        "Authorization": str(tk)}
    response = requests.get(url, headers=headers)
    if response.status_code != 200:
        print('error: ' + str(response.status_code))
    else:
        print('User List Loaded Successfully')
        #jprint(response.json()
        df = pd.DataFrame(response.json()['data'], columns=['Date', sheet])
        df['Date'] = [datetime.fromtimestamp(x) for x in df['Date']]
               
    wb= openpyxl.load_workbook('Mothly_Report_Data.xlsx')
    ws= wb[sheet]
    print(ws['A4'].value)
    ws['A4']='Date'
    ws['B4']=sheet
    print(ws['A4'].value)
    j=5
    for i in range( 0,len(df)):
               ws.cell(row=j , column=1).value=df['Date'][i]
               ws.cell(row=j , column=2).value=df[sheet][i]
               j=j+1
    wb.save('Mothly_Report_Data.xlsx')

production(midpv1,'Midstream_PA_PV1')  
production(durbpv1,'Durbanville_PA_PV1') 
production(durbpv1,'Durbanville_PA_PV2') 
production(verpv1,'Vergelegen_PA_PV1')
production(verpv2,'Vergelegen_PA_PV2')
production(herpv1,'Hermanus_PA_PV1')
production(higpv1,'Highveld_PA_PV1')
production(higpv2,'Highveld_PA_PV2')
production(tznpv1,'Tzaneen_PA_PV1')
# Out:
# User List Loaded Successfully
# 2022-12-31 18:00:01
# Date
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15548\592134737.py in <module>
#      25     wb.save('Mothly_Report_Data.xlsx')
#      26
# ---> 27 production(midpv1,'Midstream_PA_PV1')
#      28 production(durbpv1,'Durbanville_PA_PV1')
#      29 production(durbpv1,'Durbanville_PA_PV2')
#
# ~\AppData\Local\Temp\ipykernel_15548\592134737.py in production(url, sheet)
#      23                ws.cell(row=j , column=2).value=df[sheet][i]
#      24                j=j+1
# ---> 25     wb.save('Mothly_Report_Data.xlsx')
#      26
#      27 production(midpv1,'Midstream_PA_PV1')
#
# ~\anaconda3\lib\site-packages\openpyxl\workbook\workbook.py in save(self, filename)
#     405         if self.write_only and not self.worksheets:
#     406             self.create_sheet()
# ...
