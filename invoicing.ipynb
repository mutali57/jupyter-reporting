# %% [raw]
# <!-- hide code

# %%
import pandas as pd
import numpy as np
import datetime
import json 
import json
import os
import jinja2
import pandas as pd
import matplotlib.pyplot as plt
import io, base64
from IPython.display import display_html
from docx.shared import Cm
from docxtpl import DocxTemplate, InlineImage
from docx.shared import Cm, Inches, Mm, Emu
from docx2pdf import convert
#from datetime import date
#from datetime import datetime
file_location=''
df=pd.read_excel("Monthly report (2).xlsm", sheet_name='Data')
df2=pd.read_excel("Monthly report (2).xlsm", sheet_name='Phase2')
df3=pd.read_excel("Monthly report (2).xlsm", sheet_name='Bleom')
df.head()
# Along with matplotlib.pyplot, for this one
# you also need to import matplotlib itself

# use the custom font
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial Narrow'


plt.show()
df['Verg_PRP50']=df['Verg_PRP50']*100
df['Mid_PRP50']=df['Mid_PRP50']*100
df['Dur_PRP50']=df['Dur_PRP50']*100
df['Her_PRP50']=df['Her_PRP50']*100
df['Hig_PRP50']=df['Hig_PRP50']*100

df.sort_values(by="Date",ascending=True)
VerDF = df[['Date', 'Verg_Energy_(kWh)', 'Verg_PR_(%)', 'Verg_Irradiated_(kWh/m²)', 'Verg_Availability_(%)', 'Verg_P50_(kWh)','Verg_estimatedPOA', 
            'Verg_PRP50', 'Ver_W kwh','VER_Total_(ZAR)','Forecast__VER_Total_ZAR4','Ver_ Availability', 'VER_ZAR/kWh'
]]
MidDF= df[['Date','Mid_(kWh)2','Mid_PR_(%)','Mid_Irradiated_(kWh/m²)','Mid_Availability_(%)','Mid_P50_(kWh)',
           'Mid_estimatedPOA','Mid_PRP50', 'Mid_W kWh','_Forecast_MID_Total_ZAR2','MID_Total_(ZAR)','Mid_Availability','Mid_ZAR/kWh']]

DurDF= df[['Date', 'Dur_Energy_produced_(kWh)','Dur_PR_(%)','Dur_Energy_Irradiated_(kWh/m²)','Dur_Availability','DUR_Total_(ZAR)'
           ,'Dur_Availability_(%)','Dur_P50_(kWh)','Dur_estimatedPOA','Dur_PRP50','Dur_ W kWh','Forecast__DUR_Total_ZAR5','DUR_ZAR/kWh']]

HerDF=df[['Date', 'Her_Energy_produced_(kWh)', 'Her_PR_(%)', 'Her_Energy_Irradiated_(kWh/m²)', 
          'Her_Availability_(%)', 'Her_P50_(kWh)','Her_estimatedPOA', 'Her_PRP50',
          'Her_ W KWh','Her_ Availability','HER__Total__(ZAR)','Forecast_HER__Total__ZAR6','HER_ZAR/kWh2']]

HigDF=df[['Date','Hig_Energy_produced_(kWh)2', 'Hig_PR_(%)','Hig_Energy_Irradiated_(kWh/m²)','Hig_Availability_(%)'
          ,'Hig_P50_(kWh)', 'Hig_estimatedPOA','Hig_PRP50','Hig_W kWh',
          'HIG_Total_(ZAR)','Forecast_HIG_Total_ZAR3','Hig_Availability','HIG_ZAR/kWh',]]

TZADF=df[['Date','TZA_Energy_produced_(kWh)','TZA ZAR/kWh']]
PMBDF=df2[['Date', 'PMB_Energy_KWh','PMB_ZAR/kWh']]
BLMDF=df3[['Date', 'PMB_Energy_KWh','PMB_ZAR/kWh']]

#VerDF = df[['Date', 'Verg_Energy_(kWh)', 'Verg_PR_(%)', 'Verg_Irradiated_(kWh/m²)', 'Verg_Availability_(%)', 'Verg_P50_(kWh)','Verg_estimatedPOA', 'Verg_PRP50']]
#month=str(datetime.datetime.now().month-1)

#df.describe()
#df=df[(df['Date'] >= '2021-01-01') & (df['Date'] <= '2022-0'+month+'-01')]
#df['Date'].dt.strftime('%Y') 

#df['Date'] = df['Date'].dt.strftime('%b %y')
#df.info()


#VerDF=VerDF[(VerDF['Date'] >= '2022-01-01') & (VerDF['Date'] <= '2022-0'+month+'-01')]
#VerDF['Date']= VerDF['Date'].dt. strftime('%b %y')
#MidDF


start_date='2023-08-01'
end_date='2023-09-01'


VerDF=VerDF[(VerDF['Date'] >= start_date) & (VerDF['Date'] <= end_date)]
MidDF=MidDF[(MidDF['Date'] >= start_date) & (MidDF['Date'] <= end_date)]
DurDF=DurDF[(DurDF['Date'] >= start_date) & (DurDF['Date'] <= end_date)]
HerDF=HerDF[(HerDF['Date'] >= start_date) & (HerDF['Date'] <= end_date)]
HigDF=HigDF[(HigDF['Date'] >= start_date) & (HigDF['Date'] <= end_date)]
TZADF=TZADF[(TZADF['Date'] >= start_date) & (TZADF['Date'] <= end_date)]
PMBDF=PMBDF[(PMBDF['Date'] >= start_date) & (PMBDF['Date'] <= end_date)]
BLMDF=BLMDF[(BLMDF['Date'] >= start_date) & (BLMDF['Date'] <= end_date)]
from datetime import timedelta, date
from datetime import datetime
print_date= date.today().strftime('%d %b %Y') 
due_date = date.today() + timedelta(days=30)
due_date
due_date= due_date.strftime('%d %b %Y')
due_date
date.today().strftime('%d %b %Y')
month=start_date
billMonth = start_date
invoiceMonth=start_date

end_date = datetime = datetime.strptime(end_date,'%Y-%m-%d')-timedelta(days=1)
end_date=end_date.strftime('%d %b %Y')

start_date=datetime.strptime(start_date,'%Y-%m-%d')
start_date=start_date.strftime('%d %b %Y')

billMonth=datetime.strptime(billMonth,'%Y-%m-%d')
billMonth=billMonth.strftime('%b %Y')

month=datetime.strptime(month,'%Y-%m-%d')
month="{:02d}".format(month.month)

invoiceMonth = datetime.strptime(invoiceMonth,'%Y-%m-%d').strftime('%B %Y')
invoiceMonth
month

VerDF['Date']= VerDF['Date'].dt.strftime('%b %y')
MidDF['Date']= MidDF['Date'].dt. strftime('%b %y')
HigDF['Date']= HigDF['Date'].dt. strftime('%b %y')
HerDF['Date']= HerDF['Date'].dt. strftime('%b %y')
DurDF['Date']= DurDF['Date'].dt. strftime('%b %y')
TZADF['Date']= TZADF['Date'].dt. strftime('%b %y')
BLMDF['Date']= BLMDF['Date'].dt. strftime('%b %y')
PMBDF['Date']= PMBDF['Date'].dt. strftime('%b %y')

def invoice(SiteDF, plant,rate, poduction ):

     
    context={}
    if plant == 'Hermanus':
        context = {
        'site_name': 'Mediclinic Hermanus',
        'location_address':'Hermanus 7200,',
        'vat_NO': '4760118184',
        'country':'South Africa',
        'quantity':round(SiteDF[poduction].values[0],2),
        'price':SiteDF[rate].values[0],
        'subtotal_amount':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0],2),
        'vat_amount':round(0.15*(SiteDF[rate].values[0]*SiteDF[poduction].values[0]),2),
        'amount_due':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0]*(1+0.15),2),
        'subtotal':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0],2),
        'issue_date':print_date,
        'site_id':'HER-001'+' - '+date.today().strftime('%Y')+'/'+month,
        'start_date':start_date,
        'billmonth':billMonth,
        'end_date':end_date,
        'due_date':due_date}
        template = DocxTemplate('TAX INVOICE Template.docx')
        template.render(context)
        template.save('INVOICE_'+plant+' '+invoiceMonth+'.docx')
        os.startfile('INVOICE_'+plant+' '+invoiceMonth+'.docx')
        convert('INVOICE_'+plant+' '+invoiceMonth+'.docx')
        return context
    elif plant=='Tzaneen':
        context = {          
        'site_name': 'Mediclinic Tzaneen',
        'location_address':'Wolkberg Drive R71,Tzaneen,8500',
        'vat_NO':4240205379,
        'country':'South Africa',
        'quantity':round(SiteDF[poduction].values[0],2),
        'price':SiteDF[rate].values[0],
        'subtotal_amount':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0],2),
        'vat_amount':round(0.15*(SiteDF[rate].values[0]*SiteDF[poduction].values[0]),2),
        'amount_due':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0]*(1+0.15),2),
        'subtotal':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0],2),
        'issue_date':print_date,
        'site_id':'TZA-001'+' - '+date.today().strftime('%Y')+'/'+month,
        'start_date':start_date,
        'billmonth':billMonth,
        'end_date':end_date,
        'due_date':due_date}
        template = DocxTemplate('TAX INVOICE Template.docx')
        template.render(context)
        template.save('INVOICE_'+plant+' '+invoiceMonth+'.docx')
        os.startfile('INVOICE_'+plant+' '+invoiceMonth+'.docx')
        convert('INVOICE_'+plant+' '+invoiceMonth+'.docx')
        return context
    elif plant=='Vergelegen':
        context = {          
        'site_name': 'Mediclinic Vergelegen ',
        'location_address':'Vergelegen, Main Road Somerset West Cape Town,',
        'vat_NO':4760118184,
        'country':'South Africa',
        'quantity':round(SiteDF[poduction].values[0],2),
        'price':SiteDF[rate].values[0],
        'subtotal_amount':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0],2),
        'vat_amount':round(0.15*(SiteDF[rate].values[0]*SiteDF[poduction].values[0]),2),
        'amount_due':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0]*(1+0.15),2),
        'subtotal':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0],2),
        'issue_date':print_date,
        'site_id':'VER-001'+' - '+date.today().strftime('%Y')+'/'+month,
        'start_date':start_date,
        'billmonth':billMonth,
        'end_date':end_date,
        'due_date':due_date}
        template = DocxTemplate('TAX INVOICE Template.docx')
        template.render(context)
        template.save('INVOICE_'+plant+' '+invoiceMonth+'.docx')
        os.startfile('INVOICE_'+plant+' '+invoiceMonth+'.docx')
        convert('INVOICE_'+plant+' '+invoiceMonth+'.docx')
        
        return context
    elif plant=='Midstream':
        context = {          
        'site_name': 'Mediclinic Midstream',
        'location_address':'Midstream Drive, Hill Boulevard Midstream Estate, Olifantsfontein,',
        'vat_NO':4310264652,
        'country':'South Africa',
        'quantity':round(SiteDF[poduction].values[0],2),
        'price':SiteDF[rate].values[0],
        'subtotal_amount':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0],2),
        'vat_amount':round(0.15*(SiteDF[rate].values[0]*SiteDF[poduction].values[0]),2),
        'amount_due':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0]*(1+0.15),2),
        'subtotal':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0],2),
        'issue_date':print_date,
        'site_id':'MID-001'+' - '+date.today().strftime('%Y')+'/'+month,
        'start_date':start_date,
        'billmonth':billMonth,
        'end_date':end_date,
        'due_date':due_date}
        template = DocxTemplate('TAX INVOICE Template.docx')
        template.render(context)
        template.save('INVOICE_'+plant+' '+invoiceMonth+'.docx')
        os.startfile('INVOICE_'+plant+' '+invoiceMonth+'.docx')
        convert('INVOICE_'+plant+' '+invoiceMonth+'.docx')
        return context
    elif plant=='Durbanville':
        context = {          
        'site_name': 'Mediclinic Durbanville ',
        'location_address':' 45 Wellington Road Durbanville Cape Town 7550 Western Cape,',
        'vat_NO':4760118184,
        'country':'South Africa',
        'quantity':round(SiteDF[poduction].values[0],2),
        'price':SiteDF[rate].values[0],
        'subtotal_amount':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0],2),
        'vat_amount':round(0.15*(SiteDF[rate].values[0]*SiteDF[poduction].values[0]),2),
        'amount_due':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0]*(1+0.15),2),
        'subtotal':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0],2),
        'issue_date':print_date,
        'site_id':'DUR-001'+' - '+date.today().strftime('%Y')+'/'+month,
        'start_date':start_date,
        'billmonth':billMonth,
        'end_date':end_date,
        'due_date':due_date}
        template = DocxTemplate('TAX INVOICE Template.docx')
        template.render(context)
        template.save('INVOICE_'+plant+' '+invoiceMonth+'.docx')
        os.startfile('INVOICE_'+plant+' '+invoiceMonth+'.docx')
        convert('INVOICE_'+plant+' '+invoiceMonth+'.docx')
        return context
    elif plant=='Pietermaritzburg':
        context = {          
        'site_name': 'Mediclinic Pietermaritzburg',
        'location_address':'90 Payn Street,Pietermaritzburg,3201',
        'vat_NO':4760118184,
        'quantity':round(SiteDF[poduction],1),
        'country':'South Africa',
        'quantity':round(SiteDF[poduction].values[0],2),
        'price':SiteDF[rate].values[0],
        'subtotal_amount':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0],2),
        'vat_amount':round(0.15*(SiteDF[rate].values[0]*SiteDF[poduction].values[0]),2),
        'amount_due':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0]*(1+0.15),2),
        'subtotal':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0],2),
        'issue_date':print_date,
        'site_id':'PMB-001'+' - '+date.today().strftime('%Y')+'/'+month,
        'start_date':start_date,
        'billmonth':billMonth,
        'end_date':end_date,
        'due_date':due_date}
        template = DocxTemplate('TAX INVOICE Template.docx')
        template.render(context)
        template.save('INVOICE_'+plant+' '+invoiceMonth+'.docx')
        os.startfile('INVOICE_'+plant+' '+invoiceMonth+'.docx')
        convert('INVOICE_'+plant+' '+invoiceMonth+'.docx')
        return context
    elif plant=='Bloemfontein':
        context = {          
        'site_name': 'Bloemfontein Mediclinic',
        'location_address':'Cnr Kellner Street & Parfitt Avenue Westdene Bloemfontein, 93011',
        'vat_NO':4760118184,
        'quantity':round(SiteDF[poduction],1),
        'country':'South Africa',
        'quantity':round(SiteDF[poduction].values[0],2),
        'price':SiteDF[rate].values[0],
        'subtotal_amount':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0],2),
        'vat_amount':round(0.15*(SiteDF[rate].values[0]*SiteDF[poduction].values[0]),2),
        'amount_due':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0]*(1+0.15),2),
        'subtotal':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0],2),
        'issue_date':print_date,
        'site_id':'BLM-001'+' - '+date.today().strftime('%Y')+'/'+month,
        'start_date':start_date,
        'billmonth':billMonth,
        'end_date':end_date,
        'due_date':due_date}
        template = DocxTemplate('TAX INVOICE Template.docx')
        template.render(context)
        template.save('INVOICE_'+plant+' '+invoiceMonth+'.docx')
        os.startfile('INVOICE_'+plant+' '+invoiceMonth+'.docx')
        convert('INVOICE_'+plant+' '+invoiceMonth+'.docx')
        return context
    elif plant=='Highveld':
        context = {          
        'site_name': 'Mediclinic Highveld',
        'location_address':'Barney Molokwane, Trichardt 2301,',
        'vat_NO':4760118184,
        'quantity':round(SiteDF[poduction],1),
        'country':'South Africa',
        'quantity':round(SiteDF[poduction].values[0],2),
        'price':SiteDF[rate].values[0],
        'subtotal_amount':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0],2),
        'vat_amount':round(0.15*(SiteDF[rate].values[0]*SiteDF[poduction].values[0]),2),
        'amount_due':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0]*(1+0.15),2),
        'subtotal':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0],2),
        'issue_date':print_date,
        'site_id':'HIG-001'+' - '+date.today().strftime('%Y')+'/'+month,
        'start_date':start_date,
        'billmonth':billMonth,
        'end_date':end_date,
        'due_date':due_date}
        template = DocxTemplate('TAX INVOICE Template.docx')
        template.render(context)
        template.save('INVOICE_'+plant+' '+invoiceMonth+'.docx')
        os.startfile('INVOICE_'+plant+' '+invoiceMonth+'.docx')
        convert('INVOICE_'+plant+' '+invoiceMonth+'.docx')
  
       
invoice(HerDF,'Hermanus','HER_ZAR/kWh2', 'Her_Energy_produced_(kWh)' ) 
invoice(MidDF,'Midstream','Mid_ZAR/kWh', 'Mid_(kWh)2' )
invoice(DurDF,'Durbanville','DUR_ZAR/kWh', 'Dur_Energy_produced_(kWh)' )
invoice(VerDF,'Vergelegen','VER_ZAR/kWh', 'Verg_Energy_(kWh)' )
invoice(HigDF,'Highveld','HIG_ZAR/kWh', 'Hig_Energy_produced_(kWh)2' )
invoice(TZADF,'Tzaneen','TZA ZAR/kWh', 'TZA_Energy_produced_(kWh)' )
invoice(PMBDF,'Pietermaritzburg','PMB_ZAR/kWh', 'PMB_Energy_KWh' )
invoice(BLMDF,'Bloemfontein','PMB_ZAR/kWh', 'PMB_Energy_KWh' )
# Out:
# ...
#   0%|          | 0/1 [00:00<?, ?it/s]
# {'site_name': 'Bloemfontein Mediclinic',
#  'location_address': 'Cnr Kellner Street & Parfitt Avenue Westdene Bloemfontein, 93011',
#  'vat_NO': 4760118184,
#  'quantity': 34060.88,
#  'country': 'South Africa',
#  'price': 1.18,
#  'subtotal_amount': 40191.84,
#  'vat_amount': 6028.78,
#  'amount_due': 46220.61,
#  'subtotal': 40191.84,
#  'issue_date': '02 Sep 2023',
#  'site_id': 'BLM-001 - 2023/08',
#  'start_date': '01 Aug 2023',
#  'billmonth': 'Aug 2023',
#  'end_date': '31 Aug 2023',
#  'due_date': '02 Oct 2023'}

# %%
PMBDF
# Out:
#         Date  PMB_Energy_KWh  PMB_ZAR/kWh
# 4 2023-07-01        10512.68          1.7
# 5 2023-08-01             NaN          1.7

# %% [markdown]
# # Period Adjustment

# %%
start_date='2022-04-01'

end_date='2022-05-01'


VerDF=VerDF[(VerDF['Date'] >= start_date) & (VerDF['Date'] <= end_date)]
MidDF=MidDF[(MidDF['Date'] >= start_date) & (MidDF['Date'] <= end_date)]
DurDF=DurDF[(DurDF['Date'] >= start_date) & (DurDF['Date'] <= end_date)]
HerDF=HerDF[(HerDF['Date'] >= start_date) & (HerDF['Date'] <= end_date)]
HigDF=HigDF[(HigDF['Date'] >= start_date) & (HigDF['Date'] <= end_date)]

from datetime import timedelta, date
from datetime import datetime
print_date= date.today().strftime('%d %b %Y') 
due_date = date.today() + timedelta(days=30)
due_date
due_date= due_date.strftime('%d %b %Y')
due_date
date.today().strftime('%d %b %Y')
month=start_date
billMonth = start_date
invoiceMonth=start_date

end_date = datetime = datetime.strptime(end_date,'%Y-%m-%d')-timedelta(days=1)
end_date=end_date.strftime('%d %b %Y')

start_date=datetime.strptime(start_date,'%Y-%m-%d')
start_date=start_date.strftime('%d %b %Y')

billMonth=datetime.strptime(billMonth,'%Y-%m-%d')
billMonth=billMonth.strftime('%b %Y')

month=datetime.strptime(month,'%Y-%m-%d')
month="{:02d}".format(month.month)

invoiceMonth = datetime.strptime(invoiceMonth,'%Y-%m-%d').strftime('%B %Y')
invoiceMonth
month

VerDF['Date']= VerDF['Date'].dt.strftime('%b %y')
MidDF['Date']= MidDF['Date'].dt. strftime('%b %y')
HigDF['Date']= HigDF['Date'].dt. strftime('%b %y')
HerDF['Date']= HerDF['Date'].dt. strftime('%b %y')
DurDF['Date']= DurDF['Date'].dt. strftime('%b %y')


def invoice(SiteDF, plant,rate, poduction ):

     
    context={}
    if plant == 'Hermanus':
        context = {
        'site_name': 'Mediclinic Hermanus',
        'location_address':'Hermanus 7200,',
        'vat_NO': '4760118184',
        'country':'South Africa',
        'quantity':round(SiteDF[poduction].values[0],2),
        'price':SiteDF[rate].values[0],
        'subtotal_amount':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0],2),
        'vat_amount':round(0.15*(SiteDF[rate].values[0]*SiteDF[poduction].values[0]),2),
        'amount_due':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0]*(1+0.15),2),
        'subtotal':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0],2),
        'issue_date':print_date,
        'site_id':'HER-001'+' - '+date.today().strftime('%Y')+'/'+month,
        'start_date':start_date,
        'billmonth':billMonth,
        'end_date':end_date,
        'due_date':due_date}
        template = DocxTemplate('TAX INVOICE Template.docx')
        template.render(context)
        template.save('INVOICE_'+plant+' '+invoiceMonth+'.docx')
        convert('INVOICE_'+plant+' '+invoiceMonth+'.docx')
        convert('INVOICE_'+plant+' '+invoiceMonth+'.docx', convert('INVOICE_'+plant+' '+invoiceMonth+'.pdf'))
        convert('pdf/')
        os.startfile('INVOICE_'+plant+' '+invoiceMonth+'.docx')
        return context
    elif plant=='Tzaneen':
        context = {          
        'site_name': 'Mediclinic Tzaneen',
        'location_address':'Wolkberg Drive R71,Tzaneen,8500',
        'vat_NO':4240205379,
        'country':'South Africa',
        'quantity':round(SiteDF[poduction].values[0],2),
        'price':SiteDF[rate].values[0],
        'subtotal_amount':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0],2),
        'vat_amount':round(0.15*(SiteDF[rate].values[0]*SiteDF[poduction].values[0]),2),
        'amount_due':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0]*(1+0.15),2),
        'subtotal':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0],2),
        'issue_date':print_date,
        'site_id':'HER-001'+' - '+date.today().strftime('%Y')+'/'+month,
        'start_date':start_date,
        'billmonth':billMonth,
        'end_date':end_date,
        'due_date':due_date}
        template = DocxTemplate('TAX INVOICE Template.docx')
        template.render(context)
        template.save('INVOICE_'+plant+' '+invoiceMonth+'.docx')
        os.startfile('INVOICE_'+plant+' '+invoiceMonth+'.docx')
    
    elif plant=='Vergelegen':
        context = {          
        'site_name': 'Mediclinic Durbanville ',
        'location_address':'Vergelegen, Main Road Somerset West Cape Town,',
        'vat_NO':4760118184,
        'country':'South Africa',
        'quantity':round(SiteDF[poduction].values[0],2),
        'price':SiteDF[rate].values[0],
        'subtotal_amount':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0],2),
        'vat_amount':round(0.15*(SiteDF[rate].values[0]*SiteDF[poduction].values[0]),2),
        'amount_due':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0]*(1+0.15),2),
        'subtotal':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0],2),
        'issue_date':print_date,
        'site_id':'HER-001'+' - '+date.today().strftime('%Y')+'/'+month,
        'start_date':start_date,
        'billmonth':billMonth,
        'end_date':end_date,
        'due_date':due_date}
        template = DocxTemplate('TAX INVOICE Template.docx')
        template.render(context)
        template.save('INVOICE_'+plant+' '+invoiceMonth+'.docx')
        os.startfile('INVOICE_'+plant+' '+invoiceMonth+'.docx')
        
        return context
    elif plant=='Midstream':
        context = {          
        'site_name': 'Mediclinic Midstream',
        'location_address':'Midstream Drive, Hill Boulevard Midstream Estate, Olifantsfontein,',
        'vat_NO':4310264652,
        'country':'South Africa',
        'quantity':round(SiteDF[poduction].values[0],2),
        'price':SiteDF[rate].values[0],
        'subtotal_amount':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0],2),
        'vat_amount':round(0.15*(SiteDF[rate].values[0]*SiteDF[poduction].values[0]),2),
        'amount_due':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0]*(1+0.15),2),
        'subtotal':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0],2),
        'issue_date':print_date,
        'site_id':'HER-001'+' - '+date.today().strftime('%Y')+'/'+month,
        'start_date':start_date,
        'billmonth':billMonth,
        'end_date':end_date,
        'due_date':due_date}
        template = DocxTemplate('TAX INVOICE Template.docx')
        template.render(context)
        template.save('INVOICE_'+plant+' '+invoiceMonth+'.docx')
        os.startfile('INVOICE_'+plant+' '+invoiceMonth+'.docx')
        return context
    elif plant=='Durbanville':
        context = {          
        'site_name': 'Mediclinic Durbanville ',
        'location_address':' 45 Wellington Road Durbanville Cape Town 7550 Western Cape,',
        'vat_NO':4760118184,
        'country':'South Africa',
        'quantity':round(SiteDF[poduction].values[0],2),
        'price':SiteDF[rate].values[0],
        'subtotal_amount':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0],2),
        'vat_amount':round(0.15*(SiteDF[rate].values[0]*SiteDF[poduction].values[0]),2),
        'amount_due':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0]*(1+0.15),2),
        'subtotal':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0],2),
        'issue_date':print_date,
        'site_id':'HER-001'+' - '+date.today().strftime('%Y')+'/'+month,
        'start_date':start_date,
        'billmonth':billMonth,
        'end_date':end_date,
        'due_date':due_date}
        template = DocxTemplate('TAX INVOICE Template.docx')
        template.render(context)
        template.save('INVOICE_'+plant+' '+invoiceMonth+'.docx')
        os.startfile('INVOICE_'+plant+' '+invoiceMonth+'.docx')
        return context
    elif plant=='Highveld':
        context = {          
        'site_name': 'Mediclinic Highveld',
        'location_address':'Barney Molokwane, Trichardt 2301,',
        'vat_NO':4760118184,
        'quantity':round(HigDF[poduction],1),
        'country':'South Africa',
        'quantity':round(SiteDF[poduction].values[0],2),
        'price':SiteDF[rate].values[0],
        'subtotal_amount':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0],2),
        'vat_amount':round(0.15*(SiteDF[rate].values[0]*SiteDF[poduction].values[0]),2),
        'amount_due':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0]*(1+0.15),2),
        'subtotal':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0],2),
        'issue_date':print_date,
        'site_id':'HER-001'+' - '+date.today().strftime('%Y')+'/'+month,
        'start_date':start_date,
        'billmonth':billMonth,
        'end_date':end_date,
        'due_date':due_date}
        template = DocxTemplate('TAX INVOICE Template.docx')
        template.render(context)
        template.save('INVOICE_'+plant+' '+invoiceMonth+'.docx')
        
        convert('INVOICE_'+plant+' '+invoiceMonth+'.docx')
        convert('INVOICE_'+plant+' '+invoiceMonth+'.docx', convert('INVOICE_'+plant+' '+invoiceMonth+'.pdf'))
        convert('pdf/')
       # os.startfile('INVOICE_'+plant+' '+invoiceMonth+'.docx')
        return context
       
invoice(HerDF,'Hermanus','HER_ZAR/kWh2', 'Her_Energy_produced_(kWh)' ) 
invoice(MidDF,'Midstream','Mid_ZAR/kWh', 'Mid_(kWh)2' )
invoice(DurDF,'Durbanville','DUR_ZAR/kWh', 'Dur_Energy_produced_(kWh)' )
invoice(VerDF,'Vergelegen','VER_ZAR/kWh', 'Verg_Energy_(kWh)' )
invoice(TZADF,'Tzaneen','HIG_ZAR/kWh', 'Hig_Energy_produced_(kWh)2' )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_756\3523660779.py in <module>
#      38 month
#      39
# ---> 40 VerDF['Date']= VerDF['Date'].dt.strftime('%b %y')
#      41 MidDF['Date']= MidDF['Date'].dt. strftime('%b %y')
#      42 HigDF['Date']= HigDF['Date'].dt. strftime('%b %y')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     180             # we're accessing the attribute of the class, i.e., Dataset.geo
#     181             return self._accessor
# --> 182         accessor_obj = self._accessor(obj)
# ...

# %%
VerDF['Date']= VerDF['Date'].dt.strftime('%b %y')
MidDF['Date']= MidDF['Date'].dt. strftime('%b %y')
HigDF['Date']= HigDF['Date'].dt. strftime('%b %y')
HerDF['Date']= HerDF['Date'].dt. strftime('%b %y')
DurDF['Date']= DurDF['Date'].dt. strftime('%b %y')

# %%
def invoice(SiteDF, plant,rate, poduction ):

     
    context={}
    if plant == 'Hermanus':
        context = {
        'site_name': 'Mediclinic Hermanus',
        'location_address':'Hermanus 7200,',
        'vat_NO': '4760118184',
        'country':'South Africa',
        'quantity':round(SiteDF[poduction].values[0],2),
        'price':SiteDF[rate].values[0],
        'subtotal_amount':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0],2),
        'vat_amount':round(0.15*(SiteDF[rate].values[0]*SiteDF[poduction].values[0]),2),
        'amount_due':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0]*(1+0.15),2),
        'subtotal':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0],2),
        'issue_date':print_date,
        'site_id':'HER-001'+' - '+date.today().strftime('%Y')+'/'+month,
        'start_date':start_date,
        'billmonth':billMonth,
        'end_date':end_date,
        'due_date':due_date}
        template = DocxTemplate('TAX INVOICE Template.docx')
        template.render(context)
        template.save('INVOICE_'+plant+' '+invoiceMonth+'.docx')
        convert('INVOICE_'+plant+' '+invoiceMonth+'.docx')
        convert('INVOICE_'+plant+' '+invoiceMonth+'.docx', convert('INVOICE_'+plant+' '+invoiceMonth+'.pdf'))
        convert('pdf/')
        os.startfile('INVOICE_'+plant+' '+invoiceMonth+'.docx')
        return context
    elif plant=='Vergelegen':
        context = {          
        'site_name': 'Mediclinic Durbanville ',
        'location_address':'Vergelegen, Main Road Somerset West Cape Town,',
        'vat_NO':4760118184,
        'country':'South Africa',
        'quantity':round(SiteDF[poduction].values[0],2),
        'price':SiteDF[rate].values[0],
        'subtotal_amount':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0],2),
        'vat_amount':round(0.15*(SiteDF[rate].values[0]*SiteDF[poduction].values[0]),2),
        'amount_due':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0]*(1+0.15),2),
        'subtotal':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0],2),
        'issue_date':print_date,
        'site_id':'HER-001'+' - '+date.today().strftime('%Y')+'/'+month,
        'start_date':start_date,
        'billmonth':billMonth,
        'end_date':end_date,
        'due_date':due_date}
        template = DocxTemplate('TAX INVOICE Template.docx')
        template.render(context)
        template.save('INVOICE_'+plant+' '+invoiceMonth+'.docx')
        os.startfile('INVOICE_'+plant+' '+invoiceMonth+'.docx')
        
        return context
    elif plant=='Midstream':
        context = {          
        'site_name': 'Mediclinic Midstream',
        'location_address':'Midstream Drive, Hill Boulevard Midstream Estate, Olifantsfontein,',
        'vat_NO':4310264652,
        'country':'South Africa',
        'quantity':round(SiteDF[poduction].values[0],2),
        'price':SiteDF[rate].values[0],
        'subtotal_amount':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0],2),
        'vat_amount':round(0.15*(SiteDF[rate].values[0]*SiteDF[poduction].values[0]),2),
        'amount_due':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0]*(1+0.15),2),
        'subtotal':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0],2),
        'issue_date':print_date,
        'site_id':'HER-001'+' - '+date.today().strftime('%Y')+'/'+month,
        'start_date':start_date,
        'billmonth':billMonth,
        'end_date':end_date,
        'due_date':due_date}
        template = DocxTemplate('TAX INVOICE Template.docx')
        template.render(context)
        template.save('INVOICE_'+plant+' '+invoiceMonth+'.docx')
        os.startfile('INVOICE_'+plant+' '+invoiceMonth+'.docx')
        return context
    elif plant=='Durbanville':
        context = {          
        'site_name': 'Mediclinic Durbanville ',
        'location_address':' 45 Wellington Road Durbanville Cape Town 7550 Western Cape,',
        'vat_NO':4760118184,
        'country':'South Africa',
        'quantity':round(SiteDF[poduction].values[0],2),
        'price':SiteDF[rate].values[0],
        'subtotal_amount':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0],2),
        'vat_amount':round(0.15*(SiteDF[rate].values[0]*SiteDF[poduction].values[0]),2),
        'amount_due':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0]*(1+0.15),2),
        'subtotal':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0],2),
        'issue_date':print_date,
        'site_id':'HER-001'+' - '+date.today().strftime('%Y')+'/'+month,
        'start_date':start_date,
        'billmonth':billMonth,
        'end_date':end_date,
        'due_date':due_date}
        template = DocxTemplate('TAX INVOICE Template.docx')
        template.render(context)
        template.save('INVOICE_'+plant+' '+invoiceMonth+'.docx')
        os.startfile('INVOICE_'+plant+' '+invoiceMonth+'.docx')
        return context
    elif plant=='Highveld':
        context = {          
        'site_name': 'Mediclinic Highveld',
        'location_address':'Barney Molokwane, Trichardt 2301,',
        'vat_NO':4760118184,
        'quantity':round(HigDF[poduction],1),
        'country':'South Africa',
        'quantity':round(SiteDF[poduction].values[0],2),
        'price':SiteDF[rate].values[0],
        'subtotal_amount':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0],2),
        'vat_amount':round(0.15*(SiteDF[rate].values[0]*SiteDF[poduction].values[0]),2),
        'amount_due':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0]*(1+0.15),2),
        'subtotal':round(SiteDF[rate].values[0]*SiteDF[poduction].values[0],2),
        'issue_date':print_date,
        'site_id':'HER-001'+' - '+date.today().strftime('%Y')+'/'+month,
        'start_date':start_date,
        'billmonth':billMonth,
        'end_date':end_date,
        'due_date':due_date}
        template = DocxTemplate('TAX INVOICE Template.docx')
        template.render(context)
        template.save('INVOICE_'+plant+' '+invoiceMonth+'.docx')
        
        convert('INVOICE_'+plant+' '+invoiceMonth+'.docx')
        convert('INVOICE_'+plant+' '+invoiceMonth+'.docx', convert('INVOICE_'+plant+' '+invoiceMonth+'.pdf'))
        convert('pdf/')
       # os.startfile('INVOICE_'+plant+' '+invoiceMonth+'.docx')
        return context
       
invoice(HerDF,'Hermanus','HER_ZAR/kWh2', 'Her_Energy_produced_(kWh)' ) 
#invoice(MidDF,'Midstream','Mid_ZAR/kWh', 'Mid_(kWh)2' )
#invoice(DurDF,'Durbanville','DUR_ZAR/kWh', 'Dur_Energy_produced_(kWh)' )
#invoice(VerDF,'Vergelegen','VER_ZAR/kWh', 'Verg_Energy_(kWh)' )
#invoice(HigDF,'Highveld','HIG_ZAR/kWh', 'Hig_Energy_produced_(kWh)2' )

# %%
docRender()
import os
os.startfile('Automated_report1.docx')
